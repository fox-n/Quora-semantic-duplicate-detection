# %% [markdown]
# ## Import

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install optuna
# %pip install wordcloud
# Out:
# Requirement already satisfied: optuna in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (4.9.0)
# Requirement already satisfied: alembic>=1.5.0 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from optuna) (1.18.5)
# Requirement already satisfied: colorlog in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from optuna) (6.12.0)
# Requirement already satisfied: numpy in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from optuna) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from optuna) (26.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from optuna) (2.0.51)
# Requirement already satisfied: tqdm in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from optuna) (4.69.1)
# Requirement already satisfied: PyYAML in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from alembic>=1.5.0->optuna) (1.3.12)
# Requirement already satisfied: typing-extensions>=4.12 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from alembic>=1.5.0->optuna) (4.16.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: wordcloud in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from wordcloud) (2.4.6)
# Requirement already satisfied: pillow in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from wordcloud) (12.3.0)
# Requirement already satisfied: matplotlib in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from wordcloud) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (26.2)
# Requirement already satisfied: pyparsing>=3 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_project.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append('..')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import paired_cosine_distances
import wordcloud
from wordcloud import WordCloud, STOPWORDS
from src.features import add_all_features
from src.utils import plot_class_split_hist, find_mismatched_cases
from src.evaluation import compute_metrics, append_to_experiment_table, plot_confusion_matrix
from src.evaluation import train_and_evaluate, quick_log_loss
from sklearn.metrics import f1_score, roc_auc_score, log_loss, confusion_matrix
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
import optuna

# %% [markdown]
# ## Data loading

# %%
raw_df = pd.read_csv('/Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/quora_question_pairs_train_.csv', index_col = 0)

# %%
raw_df
# Out:
#           qid1    qid2                                          question1  \
# id
# 332278  459256  459257    The Iliad and the Odyssey in the Greek culture?
# 196656  297402  297403  What is practical management and what is strat...
# 113125  184949  184950                   How useful is MakeUseOf Answers?
# 266232  101283  163744  Which is the best place to reside in India and...
# 122738   17811   27517  Why do so many people ask questions on Quora t...
# ...        ...     ...                                                ...
# 111701  182893  182894  What are the major stereotypes people have abo...
# 90934   152504  152505  What are some of the best and most creative pr...
# 363857  493887  493888      Why is there a road named Aurangzeb in Delhi?
# 29409    54414   54415  What are the tips given to a teacher to satisf...
# 402019  535463  535464  Will Tiffany Trump's new Secret Service protec...
#
#                                                 question2  is_duplicate
# id
# 332278  How do I prove that the pairs of three indepen...             0
# 196656  What are the practical aspects of strategic ma...             0
# 113125  Is there any Q&A site that is not Yahoo answer...             0
# 266232         Which ia the best place to visit in India?             0
# 122738  Why don't many people posting questions on Quo...             1
# ...                                                   ...           ...
# 111701  What are the major stereotypes people have abo...             0
# 90934   Which is one of the worst and most insensible ...             0
# 363857  How do you justify naming a road after Aurangzeb?             0
# 29409   Can a high school teacher legally force studen...             0
# 402019  Why isn't polylactic acid being used more, in ...             0
#
# [323432 rows x 5 columns]

# %% [markdown]
# ## EDA

# %%
raw_df.describe()
# Out:
#                 qid1           qid2   is_duplicate
# count  323432.000000  323432.000000  323432.000000
# mean   217326.769030  221048.081142       0.369197
# std    157709.127417  159882.933077       0.482588
# min         1.000000       2.000000       0.000000
# 25%     74614.750000   74859.500000       0.000000
# 50%    192394.500000  197271.500000       0.000000
# 75%    346599.250000  354727.000000       1.000000
# max    537932.000000  537933.000000       1.000000

# %%
raw_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 323432 entries, 332278 to 402019
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   qid1          323432 non-null  int64
#  1   qid2          323432 non-null  int64
#  2   question1     323431 non-null  str
#  3   question2     323430 non-null  str
#  4   is_duplicate  323432 non-null  int64
# dtypes: int64(3), str(2)
# memory usage: 51.8 MB

# %%
#searching for rows with null values
print(raw_df.isnull().sum())
# Out:
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
# indices of rows with null values
null_idx = raw_df.isnull().any(axis=1)
print(raw_df[null_idx])
# Out:
#           qid1    qid2                         question1  \
# id
# 363362  493340  493341                               NaN
# 201841  303951  174364  How can I create an Android app?
# 105780  174363  174364    How can I develop android app?
#
#                                                 question2  is_duplicate
# id
# 363362  My Chinese name is Haichao Yu. What English na...             0
# 201841                                                NaN             0
# 105780                                                NaN             0

# %%
#deleting the row with null values ​​and overwrite the dataframe
raw_df = raw_df.dropna(subset=['question1', 'question2']).copy()

# %% [markdown]
# ### Conclusion:
# Out of 323432 rows, only 3 had missing values. Removing them would not affect the solution of the problem, so I removed them

# %%
#Checking class imbalance
raw_df.is_duplicate.value_counts(normalize=True)
# Out:
# is_duplicate
# 0    0.6308
# 1    0.3692
# Name: proportion, dtype: float64

# %%
raw_df.is_duplicate.value_counts().plot(kind='bar')
plt.title('Classes distribution')
plt.xticks([0,1], ['Not duplicate', 'Duplicate'])
# Out:
# ([<matplotlib.axis.XTick at 0x15b2ad2b0>,
#   <matplotlib.axis.XTick at 0x15b00fb10>],
#  [Text(0, 0, 'Not duplicate'), Text(1, 0, 'Duplicate')])

# %% [markdown]
# ## Feature generation & more EDA

# %%
add_all_features(raw_df, q1_col="question1", q2_col="question2")
# Out:
#           qid1    qid2                                          question1  \
# id
# 332278  459256  459257    The Iliad and the Odyssey in the Greek culture?
# 196656  297402  297403  What is practical management and what is strat...
# 113125  184949  184950                   How useful is MakeUseOf Answers?
# 266232  101283  163744  Which is the best place to reside in India and...
# 122738   17811   27517  Why do so many people ask questions on Quora t...
# ...        ...     ...                                                ...
# 111701  182893  182894  What are the major stereotypes people have abo...
# 90934   152504  152505  What are some of the best and most creative pr...
# 363857  493887  493888      Why is there a road named Aurangzeb in Delhi?
# 29409    54414   54415  What are the tips given to a teacher to satisf...
# 402019  535463  535464  Will Tiffany Trump's new Secret Service protec...
#
#                                                 question2  is_duplicate  \
# id
# 332278  How do I prove that the pairs of three indepen...             0
# 196656  What are the practical aspects of strategic ma...             0
# 113125  Is there any Q&A site that is not Yahoo answer...             0
# 266232         Which ia the best place to visit in India?             0
# 122738  Why don't many people posting questions on Quo...             1
# ...                                                   ...           ...
# 111701  What are the major stereotypes people have abo...             0
# 90934   Which is one of the worst and most insensible ...             0
# 363857  How do you justify naming a road after Aurangzeb?             0
# 29409   Can a high school teacher legally force studen...             0
# 402019  Why isn't polylactic acid being used more, in ...             0
#
#         question1_len  question2_len  len_dif  common_words  \
# id
# 332278             47             81      -34           0.0
# 196656             62             55        7           3.0
# 113125             32             78      -46           0.0
# 266232             51             42        9           2.0
# 122738            159             68       91           4.0
# ...               ...            ...      ...           ...
# 111701             90             89        1           5.0
# 90934              84             86       -2           1.0
# 363857             45             49       -4           1.0
# 29409              76             90      -14           2.0
# 402019            130             83       47           0.0
#
#         jaccard_similarity  word_match_share  bigrams_common  \
# id
# 332278            0.000000          0.000000             0.0
# 196656            0.600000          0.375000             1.0
# 113125            0.000000          0.000000             0.0
# 266232            0.250000          0.200000             1.0
# 122738            0.235294          0.190476             1.0
# ...                    ...               ...             ...
# 111701            0.714286          0.416667             3.0
# 90934             0.111111          0.100000             0.0
# 363857            0.142857          0.125000             0.0
# 29409             0.142857          0.125000             0.0
# 402019            0.000000          0.000000             0.0
#
#         bigram_jaccard_similarity  bigram_word_match_share  cosine_similarity
# id
# 332278                   0.000000                 0.000000           0.000000
# 196656                   0.200000                 0.166667           0.827243
# 113125                   0.000000                 0.000000           0.149953
# 266232                   0.142857                 0.125000           0.345153
# 122738                   0.055556                 0.052632           0.233961
# ...                           ...                      ...                ...
# 111701                   0.428571                 0.300000           0.736964
# 90934                    0.000000                 0.000000           0.415535
# 363857                   0.000000                 0.000000           0.569104
# 29409                    0.000000                 0.000000           0.313650
# 402019                   0.000000                 0.000000           0.000000
#
# [323429 rows x 15 columns]

# %%
print(raw_df['question1_len'].describe())
# Out:
# count    323429.000000
# mean         59.531761
# std          29.921286
# min           1.000000
# 25%          39.000000
# 50%          52.000000
# 75%          72.000000
# max         623.000000
# Name: question1_len, dtype: float64

# %%
print(raw_df['question2_len'].describe())
# Out:
# count    323429.000000
# mean         60.123242
# std          33.889595
# min           1.000000
# 25%          39.000000
# 50%          51.000000
# 75%          72.000000
# max        1169.000000
# Name: question2_len, dtype: float64

# %%
#deviding full test set on 2 subsets: duplicates and not_duplicates

duplicates = raw_df[raw_df['is_duplicate'] == 1]
not_duplicates = raw_df[raw_df['is_duplicate'] == 0]

# %% [markdown]
# #### Analysis of statistical moments of duplicates and not_duplicates

# %%
plt.figure(figsize=(10,8))

plt.subplot(2, 2, 1)
plot_class_split_hist(duplicates, not_duplicates, 'question1_len')

plt.subplot(2, 2, 2)
plot_class_split_hist(duplicates, not_duplicates, 'question2_len')

plt.subplot(2, 1, 2)
plot_class_split_hist(duplicates, not_duplicates, 'len_dif')

plt.tight_layout()
plt.show()

# %%
print(f'Q1 length variance in duplicates: {duplicates['question1_len'].var()}')
print(f'Q1 length variance in not_duplicates: {not_duplicates['question1_len'].var()}')
# Out:
# Q1 length variance in duplicates: 544.3865850328837
# Q1 length variance in not_duplicates: 1058.9736062179281

# %%
print(f'Q2 length variance in duplicates: {duplicates['question2_len'].var()}')
print(f'Q2 length variance in not_duplicates: {not_duplicates['question2_len'].var()}')
# Out:
# Q2 length variance in duplicates: 540.8729156994409
# Q2 length variance in not_duplicates: 1455.9419173519248

# %%
print(f'Q1 length kurtosis in duplicates: {duplicates['question1_len'].kurtosis()}')
print(f'Q1 length kurtosis in not_duplicates: {not_duplicates['question1_len'].kurtosis()}')
# Out:
# Q1 length kurtosis in duplicates: 4.171344166726708
# Q1 length kurtosis in not_duplicates: 4.6548898572360144

# %%
print(f'Q2 length kurtosis in duplicates: {duplicates['question2_len'].kurtosis()}')
print(f'Q2 length kurtosis in not_duplicates: {not_duplicates['question2_len'].kurtosis()}')
# Out:
# Q2 length kurtosis in duplicates: 3.702451437092854
# Q2 length kurtosis in not_duplicates: 50.62466344406163

# %%
print(f'Length difference Q1-Q2 variance in duplicates: {duplicates['len_dif'].var()}')
print(f'Length difference Q1-Q2 variance in not_duplicates: {not_duplicates['len_dif'].var()}')
# Out:
# Length difference Q1-Q2 variance in duplicates: 380.5788105790839
# Length difference Q1-Q2 variance in not_duplicates: 1460.0427132430757

# %%
print(f'Length difference Q1-Q2 kurtosis in duplicates {duplicates['len_dif'].kurtosis()}')
print(f'Length difference Q1-Q2 kurtosis in not_duplicates: {not_duplicates['len_dif'].kurtosis()}')
# Out:
# Length difference Q1-Q2 kurtosis in duplicates 4.798909321034921
# Length difference Q1-Q2 kurtosis in not_duplicates: 39.13918674415612

# %% [markdown]
# #### Unique words analysis

# %%
Q1_Q2_series = pd.concat([raw_df['question1'], raw_df['question2']], ignore_index=True)

# %%
Q1_Q2_series
# Out:
# 0           The Iliad and the Odyssey in the Greek culture?
# 1         What is practical management and what is strat...
# 2                          How useful is MakeUseOf Answers?
# 3         Which is the best place to reside in India and...
# 4         Why do so many people ask questions on Quora t...
#                                 ...
# 646853    What are the major stereotypes people have abo...
# 646854    Which is one of the worst and most insensible ...
# 646855    How do you justify naming a road after Aurangzeb?
# 646856    Can a high school teacher legally force studen...
# 646857    Why isn't polylactic acid being used more, in ...
# Length: 646858, dtype: str

# %%
#conversion to vectors
vectorizer = CountVectorizer(stop_words='english')

vect_questions = vectorizer.fit(Q1_Q2_series)

vect_q1 = vectorizer.transform(raw_df.question1)
vect_q2 = vectorizer.transform(raw_df.question2)

# %%
print(f"Total number of unique words: {len(vectorizer.vocabulary_)}")
# Out:
# Total number of unique words: 77733

# %%
total_matrix = vect_q1 + vect_q2
word_freq = total_matrix.sum(axis=0).A1
most_freq_words = pd.Series(word_freq, index=vectorizer.get_feature_names_out())

# %%
plt.figure(figsize=(10,8))
plt.subplot(2, 1, 1)
most_freq_words.sort_values(ascending=False).head(20).plot(kind='barh')
plt.gca().invert_yaxis()
plt.title('The most used words')


plt.subplot(2, 1, 2)
most_freq_words.sort_values(ascending=True).head(20).plot(kind='barh')
plt.gca().invert_yaxis()
plt.title('The least used words')
# Out:
# Text(0.5, 1.0, 'The least used words')

# %% [markdown]
# Observation:
# - classes are unbalanced
# - question length distributions are right-skewed
# - duplicate class length distribution has lower variance and higher kurtosis
# - entire question set has 77733 (without stop_words='english') unique words
# - least frequently used words are sets of numbers and symbols (non-Latin)

# %% [markdown]
# ## Q1 vs Q2 comparison

# %%
#Defining the number of common words and part of common words relatively to all words in Q1 and Q2
plt.figure(figsize=(10,8))

plt.subplot(2, 2, 1)
plot_class_split_hist(duplicates, not_duplicates, 'common_words')

plt.subplot(2, 2, 2)
plot_class_split_hist(duplicates, not_duplicates, 'jaccard_similarity')

plt.subplot(2, 1, 2)
plot_class_split_hist(duplicates, not_duplicates, 'word_match_share')

plt.tight_layout()
plt.show()

# %%
#cosine similarity

plt.figure(figsize=(10,8))

plot_class_split_hist(duplicates, not_duplicates, 'cosine_similarity')

plt.tight_layout()
plt.show()

# %% [markdown]
# Observation:
# jaccard_similarity, word_match_share have different distributions for duplicate/not duplicate classes, so they can be informative features for the model. For the common_words distribution, the difference is not so noticeable, but I will leave this feature as well.
# cosine_similarity - has the largest difference in distributions for duplicates and non-duplicates.

# %%
#bigram conparison

plt.figure(figsize=(10,8))

plt.subplot(2, 2, 1)
plot_class_split_hist(duplicates, not_duplicates, 'bigrams_common')

plt.subplot(2, 2, 2)
plot_class_split_hist(duplicates, not_duplicates, 'bigram_jaccard_similarity')

plt.subplot(2, 1, 2)
plot_class_split_hist(duplicates, not_duplicates, 'bigram_word_match_share')

plt.tight_layout()
plt.show()

# %% [markdown]
# Observation: bigrams turned out to be a not very informative feature because they are not sensitive to paraphrasing and are sensitive to word order, so in most cases questions do not have common bigrams.

# %%
#building a wordcloud for duplicates and non-duplicates

cloud_duplicates = ''.join(duplicates['question1'].tolist() + duplicates['question2'].tolist())
cloud_not_duplicates = ''.join(not_duplicates['question1'].tolist() + not_duplicates['question2'].tolist())

# %%
wc_duplicates = WordCloud(
    width =1000,
    height = 600,
    background_color = 'white',
    stopwords = STOPWORDS
    ).generate(cloud_duplicates)

wc_not_duplicates = WordCloud(
    width = 1000,
    height = 600,
    background_color = 'white',
    stopwords = STOPWORDS
    ).generate(cloud_not_duplicates)

plt.subplot(2,1,1)
plt.imshow(wc_duplicates, interpolation='bilinear')
plt.title('Duplicates WordCloud')
plt.axis('off')

print('\n')

plt.subplot(2,1,2)
plt.imshow(wc_not_duplicates, interpolation='bilinear')
plt.title('Not_Duplicates WordCloud')
plt.axis('off')

plt.show()

# %% [markdown]
# Observation:
# WordCloud showed that both categories have a similar set of words. That is, the general search topic coincides for all questions, the difference should be sought in the pairs of questions.

# %% [markdown]
# ## Search for cases where similarity does not match the label

# %%
false_similar_jac = find_mismatched_cases(raw_df, 'jaccard_similarity', 0.5, direction='above', target_label=0)

false_similar_cos = find_mismatched_cases(raw_df, 'cosine_similarity', 0.6, direction='above', target_label=0)

false_unsimilar_jac = find_mismatched_cases(raw_df, 'jaccard_similarity', 0.1, direction='below', target_label=1)

false_unsimilar_cos = find_mismatched_cases(raw_df, 'cosine_similarity', 0.2, direction='below', target_label=1)

# %%
false_similar_jac[['question1', 'question2', 'jaccard_similarity']]
# Out:
#                                                 question1  \
# id
# 196656  What is practical management and what is strat...
# 239687                           When did you join Quora?
# 366190  What are the disadvantages of hiring foreign w...
# 119588  What universities does Spectrum Brands recruit...
# 331082       What are some home remedies for braces pain?
# ...                                                   ...
# 48765   What are the best brands for Punching bags in UK?
# 383049                                 How is life going?
# 9428                       How can I find a job in China?
# 212748  Do employees at Safe Bulkers have a good work-...
# 111701  What are the major stereotypes people have abo...
#
#                                                 question2  jaccard_similarity
# id
# 196656  What are the practical aspects of strategic ma...            0.600000
# 239687                              Why did I join Quora?            1.000000
# 366190  What are the advantages of hiring foreign work...            0.600000
# 119588  What universities does Boulder Brands recruit ...            0.833333
# 331082         What are the home remedies for heels pain?            0.600000
# ...                                                   ...                 ...
# 48765   What are the best brands for Punching bags in ...            0.666667
# 383049                            Where is my life going?            1.000000
# 9428             How can one find a job outside of China?            0.666667
# 212748  Do employees at Scorpio Bulkers have a good wo...            0.818182
# 111701  What are the major stereotypes people have abo...            0.714286
#
# [24767 rows x 3 columns]

# %%
false_similar_cos[['question1', 'question2', 'cosine_similarity']]
# Out:
#                                                 question1  \
# id
# 196656  What is practical management and what is strat...
# 241523              Can XY chromosomes change to XX ones?
# 239687                           When did you join Quora?
# 298798        How do I download free movies from torrent?
# 86769      What is the skateboarding scene in India like?
# ...                                                   ...
# 383049                                 How is life going?
# 9428                       How can I find a job in China?
# 212748  Do employees at Safe Bulkers have a good work-...
# 15401       How do I move past my fear and learn options?
# 111701  What are the major stereotypes people have abo...
#
#                                                 question2  cosine_similarity
# id
# 196656  What are the practical aspects of strategic ma...           0.827243
# 241523  What are XX and XY chromosomes? How are they d...           0.861547
# 239687                              Why did I join Quora?           1.000000
# 298798                    How do I download from torrent?           0.778948
# 86769             What are the best skateboarding movies?           0.618402
# ...                                                   ...                ...
# 383049                            Where is my life going?           1.000000
# 9428             How can one find a job outside of China?           0.726931
# 212748  Do employees at Scorpio Bulkers have a good wo...           0.882781
# 15401                          How do you move past fear?           0.769423
# 111701  What are the major stereotypes people have abo...           0.736964
#
# [57873 rows x 3 columns]

# %%
false_unsimilar_jac[['question1', 'question2', 'jaccard_similarity']].head(20)
# Out:
#                                                 question1  \
# id
# 307736                       How can I get a PhD quickly?
# 255552  After our 1st date that lasted only 90 mins fo...
# 163739                         How do you get top writer?
# 381292  How much time do you need to spend on Quora to...
# 31249   Would a guy try and kiss you and text right af...
# 83857                  How do I become mentally stronger?
# 131981               How can I get my hair to be healthy?
# 200431                  How do i get myself a girlfriend?
# 249584               My cat died, how do I get over this?
# 148517                            How can I get a hacker?
# 331992                    What should I do I am confused?
# 223815  How would you take over the world starting fro...
# 201342  How likely would it be only one language in fu...
# 365145  Can we achieve world peace if the world's popu...
# 399437                  How do i get myself a girlfriend?
# 25911   How do I get along with my teacher in university?
# 210354       When will India take back PoK from Pakistan?
# 52254                        Why do people become famous?
# 217636                    How do individuals get patents?
# 339101                    What is something you never do?
#
#                                                 question2  jaccard_similarity
# id
# 307736                               How can I get a PhD?            0.000000
# 255552  Would a guy try and kiss you and text right af...            0.090909
# 163739  How do I become the Top Writer on Quora, get m...            0.000000
# 381292         How do you become the top writer on Quora?            0.000000
# 31249   If a man texted five minutes after the first d...            0.095238
# 83857                   How can I become strong mentally?            0.000000
# 131981              What should I do to get healthy hair?            0.000000
# 200431                   How do I get a girl's attention?            0.000000
# 249584            How can I get over the death of my cat?            0.000000
# 148517                How do I get in touch with hackers?            0.000000
# 331992                       I am confused,what can i do?            0.000000
# 223815                     How can I take over the world?            0.000000
# 201342  In the future, is it possible that there is on...            0.000000
# 365145  If the world has only One religion, The God, t...            0.090909
# 399437                 How do you get a girl to like you?            0.000000
# 25911   What is the best way to get along with your te...            0.000000
# 210354  Can India get its occupied land back from neig...            0.090909
# 52254               How can I become famous in the world?            0.000000
# 217636                          How can one get a patent?            0.000000
# 339101             What is something you have never done?            0.000000

# %%
false_unsimilar_cos[['question1', 'question2', 'cosine_similarity']].head(20)
# Out:
#                                                 question1  \
# id
# 64894   Is the human life more important than the life...
# 342038  What are the best online sites to learn comput...
# 164040                How do I lose weight ayurvedically?
# 397565  What are the differences between BI tools and ...
# 201003                        How does crowdfunding work?
# 8386             What is a good first car for a teen guy?
# 236667   What are the effects of demonetization in India?
# 112786      How can I speaking fluently speaking English?
# 334807      Is their any way you can PM someone on Quora?
# 145560          Can I get pregnant a week after my cycle?
# 350926  What are some of the most upvoted answers you ...
# 371121  If you could go back in time and change one ev...
# 226339          How do I get rid of acne and acne causes?
# 31804   Is there a scientific name for what existed be...
# 336872  Which is the best book to learn programming in...
# 25217   What is the best way to memorize or remember w...
# 364434  What is the difference between netbook and lap...
# 248940      How many employees does Quora currently have?
# 179714                 Who are your best friends and why?
# 246573                  What does an actuary actually do?
#
#                                                 question2  cosine_similarity
# id
# 64894   Do human lives have any more value than other ...           0.125274
# 342038  What is the best website to learn coding indep...           0.173192
# 164040                How can I loose weight for wedding?           0.180115
# 397565  What is the difference between Business Analyt...           0.188860
# 201003      How does a crowd-funding portal/website work?           0.180094
# 8386                What's the ideal first car for teens?           0.195494
# 236667                  Is demonetisation good for India?           0.156610
# 112786          How can I continue to improve my English?           0.146121
# 334807        How do I personal message someone on Quora?           0.190412
# 145560  Can I get pregnant 3 days after period if I bl...           0.188713
# 350926        Which is the most up voted answer in Quora?           0.124287
# 371121  If you could go back in time and re-do any sin...           0.171494
# 226339           How do I get rid of pimples permanently?           0.166698
# 31804   How was our universe before the Big Bang? Was ...           0.199868
# 336872  What are the best books to learn c programing ...           0.195647
# 25217      What is the best way to retain what you learn?           0.166707
# 364434  What is the difference between netbooks and la...           0.102989
# 248940                  How many staff does Quora employ?           0.184047
# 179714                             Who is my best friend?           0.173692
# 246573                              What do actuaries do?           0.178702

# %% [markdown]
# Observations
# - cases where there is no duplicate tag, but there is a high jaccard_similarity or cosine_similarity - this is a sentence with 1 or a pair of words that are different, and this changes the context or meaning of the sentence
#
# - cases where there is a duplicate tag, but a low jaccard_similarity or cosine_similarity, the sentences use synonymous expressions that mean the same thing, or different parts of speech with a common root, or metaphors

# %% [markdown]
# ## Base models

# %%
# deviding of train daset on train and val
X = raw_df.drop(columns=['is_duplicate'])
y = raw_df['is_duplicate']
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# #### Model 0: majority class baseline

# %%
majority_class = y_train.value_counts().idxmax()
y_pred_majority = np.full(len(y_val), majority_class)
y_prob_majority = np.full(len(y_val), y_train.mean())

# %%
results_model_0 = compute_metrics(y_val, y_pred_majority, y_prob_majority, 'Model 0: Majority class baseline', threshold=None)
# Out:
# model: Model 0: Majority class baseline
#
# threshold: None
#
# params: None
#
# train_time_sec: None
#
# train_f1: None
#
# train_roc_auc: None
#
# train_log_loss: None
#
# f1: 0.0
#
# roc_auc: 0.5
#
# log_loss: 0.6585279444319896

# %%
plot_confusion_matrix(y_val, y_pred_majority, 'Model 0: Majority class baseline')

# %%
append_to_experiment_table(results_model_0, path='/Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/reports/experiment_table.csv')

# %% [markdown]
# #### Model 1: cosine similarity

# %%
#chosing of threshold

best_f1, best_threshold = 0, 0
for threshold in np.arange(0.1, 0.9, 0.05):
    y_pred_temp = (X_train['cosine_similarity'] > threshold).astype(int)
    f1 = f1_score(y_train, y_pred_temp)
    if f1 > best_f1:
        best_f1, best_threshold = f1, threshold

#prediction on val
y_pred = (X_val['cosine_similarity'] > best_threshold).astype(int)

# %%
#metrics calculation

results_model_1 = compute_metrics(y_val, y_pred, X_val['cosine_similarity'], 'Model 1: cosine similarity', threshold=best_threshold)
# Out:
# model: Model 1: cosine similarity
#
# threshold: 0.3500000000000001
#
# params: None
#
# train_time_sec: None
#
# train_f1: None
#
# train_roc_auc: None
#
# train_log_loss: None
#
# f1: 0.63113377147741
#
# roc_auc: 0.73442959225784
#
# log_loss: 1.1061281457092904

# %%
plot_confusion_matrix(y_val, y_pred, 'Model 1: cosine similarity')

# %%
append_to_experiment_table(results_model_1, path='/Users/nadiiababanska/Desktop/claude_coowork/ML_final_project/reports/experiment_table.csv')

# %% [markdown]
# #### Model 2 - XGBoost baseline

# %%
feature_cols = ['question1_len', 'question2_len', 'len_dif', 'common_words',
                 'jaccard_similarity', 'word_match_share', 'bigrams_common',
                 'bigram_jaccard_similarity', 'bigram_word_match_share', 'cosine_similarity']

X_train_xgb = X_train[feature_cols]
X_val_xgb = X_val[feature_cols]

# %%
model_xgb = XGBClassifier(random_state=42)
model_xgb_fitted, results_model_2 = train_and_evaluate(model_xgb, X_train_xgb, y_train, X_val_xgb, y_val, 'Model 2 - XGBoost baseline', threshold=None)
# Out:
# model: Model 2 - XGBoost baseline
#
# threshold: None
#
# params: {'objective': 'binary:logistic', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': None, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': True, 'eval_metric': None, 'feature_types': None, 'feature_weights': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': None, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': None, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': None, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': None, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# train_time_sec: 0.5167269706726074
#
# train_f1: 0.7174153388767595
#
# train_roc_auc: 0.8549378139226704
#
# train_log_loss: 0.4314707815647125
#
# f1: 0.7009504602916736
#
# roc_auc: 0.837538379706826
#
# log_loss: 0.4497517943382263

# %% [markdown]
# #### XGBoost parameters tuning with Optuna

# %%
def objective(trial):
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'random_state': 42,
    }
    model = XGBClassifier(**params)
    return quick_log_loss(model, X_train_xgb, y_train, X_val_xgb, y_val)

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=10)
# Out:
# [I 2026-07-24 23:31:41,844] A new study created in memory with name: no-name-523ce849-3ecf-44ed-bd63-fae181d85f24
# [I 2026-07-24 23:31:43,620] Trial 0 finished with value: 0.4592822790145874 and parameters: {'max_depth': 4, 'learning_rate': 0.020144575166485032, 'n_estimators': 468, 'subsample': 0.8012248202364045, 'colsample_bytree': 0.6287937405969152}. Best is trial 0 with value: 0.4592822790145874.
# [I 2026-07-24 23:31:44,450] Trial 1 finished with value: 0.4831503629684448 and parameters: {'max_depth': 6, 'learning_rate': 0.01237869680026234, 'n_estimators': 135, 'subsample': 0.7471016318631335, 'colsample_bytree': 0.6417948668493694}. Best is trial 0 with value: 0.4592822790145874.
# [I 2026-07-24 23:31:44,919] Trial 2 finished with value: 0.45723530650138855 and parameters: {'max_depth': 4, 'learning_rate': 0.10298378913811748, 'n_estimators': 107, 'subsample': 0.6023582508817794, 'colsample_bytree': 0.9337310374873043}. Best is trial 2 with value: 0.45723530650138855.
# [I 2026-07-24 23:31:46,501] Trial 3 finished with value: 0.4524204730987549 and parameters: {'max_depth': 5, 'learning_rate': 0.05927509499534148, 'n_estimators': 265, 'subsample': 0.8674816052294284, 'colsample_bytree': 0.6390118602953894}. Best is trial 3 with value: 0.4524204730987549.
# [I 2026-07-24 23:31:49,611] Trial 4 finished with value: 0.45401063561439514 and parameters: {'max_depth': 9, 'learning_rate': 0.010111838265975842, 'n_estimators': 320, 'subsample': 0.6840610043200895, 'colsample_bytree': 0.756526204080236}. Best is trial 3 with value: 0.4524204730987549.
# [I 2026-07-24 23:31:50,524] Trial 5 finished with value: 0.4661960303783417 and parameters: {'max_depth': 3, 'learning_rate': 0.031504583184812335, 'n_estimators': 224, 'subsample': 0.88457657922869, 'colsample_bytree': 0.8114063576225669}. Best is trial 3 with value: 0.4524204730987549.
# [I 2026-07-24 23:31:52,947] Trial 6 finished with value: 0.4541406035423279 and parameters: {'max_depth': 6, 'learning_rate': 0.29925769335340235, 'n_estimators': 451, 'subsample': 0.8549245722863521, 'colsample_bytree': 0.8368239821479294}. Best is trial 3 with value: 0.4524204730987549.
# [I 2026-07-24 23:31:57,041] Trial 7 finished with value: 0.45783868432044983 and parameters: {'max_depth': 10, 'learning_rate': 0.09199523781553966, 'n_estimators': 410, 'subsample': 0.6256044005383242, 'colsample_bytree': 0.9404842835164973}. Best is trial 3 with value: 0.4524204730987549.
# [I 2026-07-24 23:31:59,578] Trial 8 finished with value: 0.44918498396873474 and parameters: {'max_depth': 8, 'learning_rate': 0.024415562819706894, 'n_estimators': 366, 'subsample': 0.9748201363647582, 'colsample_bytree': 0.9205341729556404}. Best is trial 8 with value: 0.44918498396873474.
# [I 2026-07-24 23:32:02,041] Trial 9 finished with value: 0.44849061965942383 and parameters: {'max_depth': 7, 'learning_rate': 0.0388220719987634, 'n_estimators': 378, 'subsample': 0.9024313105086541, 'colsample_bytree': 0.9926805157655891}. Best is trial 9 with value: 0.44849061965942383.

# %%
print(study.best_params)
print(study.best_value)
# Out:
# {'max_depth': 7, 'learning_rate': 0.0388220719987634, 'n_estimators': 378, 'subsample': 0.9024313105086541, 'colsample_bytree': 0.9926805157655891}
# 0.44849061965942383

# %%
best_xgb_model = XGBClassifier(**study.best_params, random_state=42)
model_xgb_tuned, results_model_2_tuned = train_and_evaluate(
    best_xgb_model, X_train_xgb, y_train, X_val_xgb, y_val,
    'Model 2: XGBoost (Optuna-tuned)'
)
# Out:
# model: Model 2: XGBoost (Optuna-tuned)
#
# threshold: None
#
# params: {'objective': 'binary:logistic', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.9926805157655891, 'device': None, 'early_stopping_rounds': None, 'enable_categorical': True, 'eval_metric': None, 'feature_types': None, 'feature_weights': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.0388220719987634, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 7, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 378, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': None, 'reg_lambda': None, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.9024313105086541, 'tree_method': None, 'validate_parameters': None, 'verbosity': None}
#
# train_time_sec: 1.8263931274414062
#
# train_f1: 0.7172487425044984
#
# train_roc_auc: 0.8532830678202794
#
# train_log_loss: 0.4336704909801483
#
# f1: 0.7045542725173211
#
# roc_auc: 0.839085179800424
#
# log_loss: 0.44849061965942383
